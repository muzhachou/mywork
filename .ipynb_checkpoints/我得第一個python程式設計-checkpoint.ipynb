# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[0,1.1,2.5,3.2,4.8]
y=[2.1,3.4,1,5,7]

# %%
plt.plot(x,y)

# %%
np.random.rand(5)
# Out:
# array([0.74738402, 0.86247648, 0.381437  , 0.07856105, 0.66478419])

# %%
plt.plot(np.random.randn(100))

# %%
x=np.random.randn(300)
y=np.random.randn(300)

# %%
plt.scatter(x,y)

# %%
x=np.linspace(-10,10,500)

# %%
y=x**2+1

# %%
plt.plot(x,y)

# %%
x=np.linspace(0,180,1000)

# %%
y=np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
x=np.linspace(-2*np.pi,2*np.pi,500)

# %%
y=np.sin(x)+1/5*np.cos(20*x + np.pi/3)*x/3

# %%
plt.plot(x,y)

# %%
θ=np.linspace(0,2*np.pi,500)

# %%
r=5
x=r*np.sin(θ)

# %%
y=r*np.cos(θ)

# %%
plt.plot(x,y)

# %%
π=np.pi
