# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
π=np.pi

# %%
θ=np.linspace(0,2*π,1000)

# %%
k=np.sin(θ)*np.cos(θ)

# %%
X=np.cos(θ)+5*k

# %%
Y=np.sin(θ)-8*k

# %%
plt.plot(X,Y)

# %%
f=np.linspace(0,30,500)

# %%
np.int_a^b x*dx
# Out:
#   File "<ipython-input-54-ead0751dfd9f>", line 1
#     np.int_a^b x*dx
#                ^
# SyntaxError: invalid syntax
